# %%
import datetime

# %%
min = 4066%60
h = 4066//60%24
d = 4066//60//24
print(f"{d} day(s), {h} hour(s), {min} minute(s)")
# Out:
# 2 day(s), 19 hour(s), 46 minute(s)

# %%
s = datetime.datetime(2180,5,7, 17, 15) - datetime.datetime(2180,5,6, 22,23)
s/60
# Out:
# datetime.timedelta(seconds=1132)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
6634093860 - 6626966400
# total_sec = 6634093860 - 1648126260  
total_sec = 1648126260 
sec = total_sec%60
total_min = (total_sec - sec)/60
min = total_min%60
total_h = (total_min - min)/60
h = total_h%24
total_d = (total_h - h)/24
d = total_d % 365
y = (total_d - d)/365
print(f"{y} year(s), {d} day(s), {h} hour(s), {min} minute(s), {sec} second(s)")
m = d / (4.3*7)
print(f"{m} month(s)")
# Out:
# 52.0 year(s), 95.0 day(s), 12.0 hour(s), 51.0 minute(s), 0 second(s)
# 3.1561461794019934 month(s)

# %%
print(1648126260 - 1648126260)
print(1651965900 - 1651962300)
# Out:
# 0
# 3600

# %%
4.3*7
# Out:
# 30.099999999999998

# %%
# total_sec = 6634093860 - 1648126260  
total_sec = 1648126260
sec = total_sec%60
total_min = (total_sec - sec)/60
min = total_min%60
total_h = (total_min - min)/60
h = total_h%24
total_d = (total_h - h)/24
d = total_d % 365
y = (total_d - d)/365
print(f"{y} year(s), {d} day(s), {h} hour(s), {min} minute(s), {sec} second(s)")
m = d / (4.3*7)
print(f"{m} month(s)")
# Out:
# 52.0 year(s), 95.0 day(s), 12.0 hour(s), 51.0 minute(s), 0 second(s)
# 3.1561461794019934 month(s)

# %%
1648126260//60//60//24//365
# Out:
# 52

# %%
datetime.datetime(2180,6,6,16,39) - datetime.datetime(2180-52,1,1,)
# Out:
# datetime.timedelta(days=19150, seconds=59940)

# %%
19150*24*3600 + 56340
# Out:
# 1654616340
