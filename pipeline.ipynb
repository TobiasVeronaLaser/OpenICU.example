# %%
from pathlib import Path

from open_icu import OpenICUProject, ExtractionStep, ConceptStep

config_path = Path.cwd() / "config" 
project_path = Path.cwd() / "output" / "project"
with OpenICUProject(project_path) as project:

    extraction_step = ExtractionStep.load(project, config_path / "extraction.yml")
    extraction_step.run()

    concept_step = ConceptStep.load(project, config_path / "concept.yml")
    concept_step.run()
# Out:
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.mean_corpuscular_hemoglobin_concentration.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.hemoglobin_a1c.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.white_blood_cell_count.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.band_form_neutrophils.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.mean_corpuscular_hemoglobin.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.red_blood_cell_count.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.prothrombin_time_per_international_normalized_ratio.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.erythrocyte_sedimentation_rate.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.lymphocytes.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.hemoglobin.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.platelet_count.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.basophils.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.erythrocyte_distribution_width.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.mean_corpuscular_volume.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.neutrophils.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.fibrinogen.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.eosinophils.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.prothrombine_time.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.hematocrit.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.partial_thromboplastin_time.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.patient_weight.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.patient_height.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.systolic_blood_pressure.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.mean_arterial_pressure.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.diastolic_blood_pressure.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.endtidal_co2.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.heart_rate.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.temperature.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.co2_partial_pressure.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.fraction_of_inspired_oxygen.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.ph_of_blood.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.lactate.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.o2_partial_pressure.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.methemoglobin.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.calcium_ionized.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.base_excess.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.totcal_co2.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.vasopressin_rate.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.dextrose_(as_d10).1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.norepinephrine_rate.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.dobutamine_duration.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.epinephrine_rate.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.norepinephrine_duration.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.antibiotics.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.insulin.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.phenylephrine_rate.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.epinephrine_duration.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.dopamine_duration.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.dopamine_rate.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.dobutamine_rate.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.gcs_verbal.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.gcs_total.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.gcs_eye.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.richmond_agitation_sedation_scale.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.gcs_motor.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.potassium.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.aspartate_aminotransferase.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.creatinine.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.creatine_kinase_mb.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.albumin.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.creatine_kinase.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.calcium.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.alanine_aminotransferase.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.bilirubin_direct.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.bicarbonate.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.c-reactive_protein.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.alkaline_phosphatase.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.troponin_i.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.chloride.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.total_bilirubin.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.phosphate.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.blood_urea_nitrogen.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.troponin_t.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.magnesium.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.glucose.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.sodium.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.urine_output.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.arterial_oxygen_saturation.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.respiratory_rate.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.ventilation_end.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.oxygen_saturation.1.0.0
# 2026-03-30 15:06:12 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.ventilation_start.1.0.0
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept mean_corpuscular_hemoglobin_concentration for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept Hemoglobin_A1C for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept white_blood_cell_count for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept band_form_neutrophils for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept mean_corpuscular_hemoglobin for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept red_blood_cell_count for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept prothrombin_time_per_international_normalized_ratio for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept erythrocyte_sedimentation_rate for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept lymphocytes for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept hemoglobin for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept platelet_count for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept basophils for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept erythrocyte_distribution_width for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept mean_corpuscular_volume for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept neutrophils for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept fibrinogen for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept eosinophils for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept prothrombine_time for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept hematocrit for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept partial_thromboplastin_time for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept patient_weight for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept patient_height for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept systolic_blood_pressure for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept mean_arterial_pressure for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept diastolic_blood_pressure for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept endtidal_CO2 for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept heart_rate for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept temperature for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept CO2_partial_pressure for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept fraction_of_inspired_oxygen for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept pH_of_blood for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept lactate for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept O2_partial_pressure for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept methemoglobin for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept calcium_ionized for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept base_excess for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept totcal_CO2 for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept vasopressin_rate for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept dextrose_(as_D10) for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept norepinephrine_rate for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept dobutamine_duration for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept epinephrine_rate for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept norepinephrine_duration for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept antibiotics for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept insulin for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept phenylephrine_rate for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept epinephrine_duration for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept dopamine_duration for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept dopamine_rate for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept dobutamine_rate for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept GCS_verbal for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept GCS_total for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept GCS_eye for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept Richmond_agitation_sedation_scale for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept GCS_motor for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept potassium for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept aspartate_aminotransferase for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept creatinine for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept creatine_kinase_MB for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept albumin for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept creatine_kinase for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept calcium for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept alanine_aminotransferase for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept bilirubin_direct for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept bicarbonate for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept C-reactive_protein for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept alkaline_phosphatase for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept troponin_I for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept chloride for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept total_bilirubin for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept phosphate for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept blood_urea_nitrogen for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept troponin_t for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept magnesium for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept glucose for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept sodium for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept urine_output for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept arterial_oxygen_saturation for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept respiratory_rate for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept ventilation_end for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept oxygen_saturation for dataset mimic-demo: no dataset-specific config found
# 2026-03-30 15:06:12 [WARNING] open_icu.steps.concept.step: skipping concept ventilation_start for dataset mimic-demo: no dataset-specific config found
