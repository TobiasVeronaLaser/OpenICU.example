# %%
from pathlib import Path

from open_icu import OpenICUProject, ExtractionStep, ConceptStep

config_path = Path.cwd() / "config" 
project_path = Path.cwd() / "output" / "project"
with OpenICUProject(project_path) as project:

    extraction_step = ExtractionStep.load(project, config_path / "extraction.yml")
    extraction_step.run()

    concept_step = ConceptStep.load(project, config_path / "concept.yml")
    concept_step.run()
# Out:
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.labevents
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.ingredientevents
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.diagnoses_icd
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.drgcodes
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.microbiologyevents
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.icustay
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.hcpcsevents
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.services
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.omr
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.admissions
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.patients
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.emar
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.chartevents
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.prescriptions
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.datetimeevent
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.inputevents
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.outputevents
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.procedureevents
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.nwicu.0.1.0.labevents
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.nwicu.0.1.0.diagnoses_icd
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.nwicu.0.1.0.icustay
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.nwicu.0.1.0.admissions
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.nwicu.0.1.0.patients
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.nwicu.0.1.0.emar
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.nwicu.0.1.0.chartevents
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.nwicu.0.1.0.prescriptions
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.nwicu.0.1.0.procedureevents
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.eicu-crd.2.0.infusiondrug
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.eicu-crd.2.0.lab
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.eicu-crd.2.0.patient
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.eicu-crd.2.0.medication
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.eicu-crd.2.0.vitalperiodic
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.antibiotics.1.0.0
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.lactate.1.0.0
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.co2_partial_pressure.1.0.0
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.methemoglobin.1.0.0
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.base_excess.1.0.0
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.ph_of_blood.1.0.0
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.o2_partial_pressure.1.0.0
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.totcal_co2.1.0.0
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.calcium_ionized.1.0.0
# 2026-03-19 14:31:24 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.fraction_of_inspired_oxygen.1.0.0
# 2026-03-19 14:31:24 [INFO] open_icu.steps.concept.step: extracting concept: antibiotics
# 2026-03-19 14:31:24 [INFO] open_icu.steps.concept.step: extracting concept: lactate
# 2026-03-19 14:31:24 [INFO] open_icu.steps.concept.step: extracting concept: CO2_partial_pressure
# 2026-03-19 14:31:24 [INFO] open_icu.steps.concept.step: extracting concept: methemoglobin
# 2026-03-19 14:31:24 [INFO] open_icu.steps.concept.step: extracting concept: base_excess
# 2026-03-19 14:31:24 [INFO] open_icu.steps.concept.step: extracting concept: pH_of_blood
# 2026-03-19 14:31:24 [INFO] open_icu.steps.concept.step: extracting concept: O2_partial_pressure
# 2026-03-19 14:31:24 [INFO] open_icu.steps.concept.step: extracting concept: totcal_CO2
# 2026-03-19 14:31:24 [INFO] open_icu.steps.concept.step: extracting concept: calcium_ionized
# 2026-03-19 14:31:24 [INFO] open_icu.steps.concept.step: extracting concept: fraction_of_inspired_oxygen
