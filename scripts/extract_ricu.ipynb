# %%
from pathlib import Path

import json
import polars as pl

# %%
# ricu concept dict
ricu_cnpt_dict_df = pl.read_json("/workspaces/OpenICU-Example/custom/python/generation/reference/concept-dict.json")
# miiv data
miiv_d_items_lf = pl.scan_csv("/workspaces/example/data/physionet.org/files/mimiciv/3.1/icu/d_items.csv.gz").with_columns((pl.col("itemid").cast(pl.Utf8) + "//" + pl.col("label")).alias("code"))
miiv_d_labitems_lf = pl.scan_csv("/workspaces/example/data/physionet.org/files/mimiciv/3.1/hosp/d_labitems.csv.gz").with_columns((pl.col("itemid").cast(pl.Utf8) + "//" + pl.col("label")).alias("code"))

# %%
def ricu_cnpt_dict_to_cust_cnpt_dict(info: pl.DataFrame, src_name: str, src_items: dict[str, pl.LazyFrame], src_item_col_name: str) -> tuple[dict, dict]:
    data: dict[str, dict] = {}
    un_src_data: dict = {}
    i = 0
    for cnpt in info.columns:
        if(cnpt_srcs := info[cnpt][0].get("sources")) and cnpt_srcs.get(src_name):
            for i in range(len(cnpt_srcs[src_name])):
                src = cnpt_srcs[src_name][i]
                cnpt_ids = src.get("ids")
                cnpt_regex = src.get("regex")
                if cnpt_ids is None and cnpt_regex is None:
                    un_src_data[cnpt] = info[cnpt]
                    continue
                cnpt_entr = info[cnpt][0]
                cnpt_cat = cnpt_entr["category"].replace(" ", "_").replace("/", "_per_")
                cnpt_name = cnpt_entr["description"].replace(" ", "_").replace("/", "_per_")
                cnpt_tbl = src["table"]

                if not data.get(cnpt_cat):
                    data[cnpt_cat] = {}

                if isinstance(cnpt_ids, str) or (isinstance(cnpt_ids, list) and isinstance(cnpt_ids[0], str)):
                    un_src_data[cnpt] = info[cnpt]
                    continue
                
                if cnpt_ids is not None:
                    cnpt_ids: list[int] = cnpt_ids if isinstance(cnpt_ids, list) else [cnpt_ids]

                if data[cnpt_cat].get(cnpt_name) is None:
                    data[cnpt_cat][cnpt_name] = []
                
                data[cnpt_cat][cnpt_name].append({
                    "name": cnpt_name,
                    "unit": cnpt_entr.get("unit"),
                    "table": cnpt_tbl,
                    "code": None,
                    "ids": cnpt_ids,
                    "src_regex": cnpt_regex,
                    "short": cnpt,
                    "min": cnpt_entr.get("min"),
                    "max": cnpt_entr.get("max"),
                })
                if cnpt_ids is not None:
                    filtered_src_items = src_items[cnpt_tbl if cnpt_tbl in src_items.keys() else "else"].filter(pl.col(src_item_col_name).is_in(cnpt_ids)).select("code").collect()
                    regex = "|".join(list(filtered_src_items["code"]))
                else:
                    regex = cnpt_regex

                data[cnpt_cat][cnpt_name][i]["code"] = "(" + regex + ")"

                if data[cnpt_cat][cnpt_name][i]["max"] is None:
                    data[cnpt_cat][cnpt_name][i]["max"] = "Inf"

                if data[cnpt_cat][cnpt_name][i]["min"] is None:
                    data[cnpt_cat][cnpt_name][i]["min"] = "-Inf"

    return (data, un_src_data)

# %%
data_by_cat = {}
un_src_data = {}

src_item_mapping = {"labevents": miiv_d_labitems_lf, "else": miiv_d_items_lf}
(data_by_cat, un_src_data) = ricu_cnpt_dict_to_cust_cnpt_dict(ricu_cnpt_dict_df, "miiv", src_item_mapping, "itemid")

# %%
data_by_cnpt = {}
for cat in data_by_cat.keys():
    for cnpt in data_by_cat[cat]:
        data_by_cnpt[cnpt] = data_by_cat[cat][cnpt]

# %%
# Overview about usable data
print("total category count:", len(data_by_cat))
for key in data_by_cat.keys():
    print("\tcategory:", key, "concept count:", len(data_by_cat[key]))
print("total concept count:", len(data_by_cnpt))
# Out:
# total category count: 9
# 	category: chemistry concept count: 21
# 	category: demographics concept count: 2
# 	category: blood_gas concept count: 9
# 	category: medications concept count: 13
# 	category: respiratory concept count: 4
# 	category: hematology concept count: 20
# 	category: output concept count: 1
# 	category: neurological concept count: 4
# 	category: vitals concept count: 6
# total concept count: 80

# %%
# Overview about unused data
print("total unused concept count:", len(un_src_data))
# Out:
# total unused concept count: 8

# %%
with open("data.json", "w") as file:
    json.dump(data_by_cat, file, indent=4, ensure_ascii=False)

# %%
def create_general_cnpt(dir_path: str | Path, name: str, unit: str, table_contents: list[dict]) -> None:
    if isinstance(unit, list):
        unit = unit[0]
    if unit == "%":
        unit = "\"%\""

    path = Path(dir_path)
    path.mkdir(parents=True, exist_ok=True)
    print(path)
    out_file = path / f"{name}.yml"

    # Existenz prüfen
    if out_file.exists():
        print(f"File already exists: {out_file}")
        return

    content = f"""name: {name}
version: 1.0.0
unit: {unit}
extension_columns:
  dataset: col("dataset")
  table: col("table")
"""

    with open(out_file, "w", encoding="utf8") as f:
        f.write(content)

    print(f"Created: {out_file}")

# %%
def create_src_specific_cnpt(dir_path: str | Path, name: str, unit: str, table_contents: list[dict]) -> None:
    if isinstance(unit, list):
        unit = unit[0]
    if unit == "%":
        unit = "\"%\""

    path = Path(dir_path)
    path.mkdir(parents=True, exist_ok=True)
    print(path)
    out_file = path / f"{name}.yml"

    # Existenz prüfen
    if out_file.exists():
        print(f"File already exists: {out_file}")
        return

    content = """mappings:
"""
    for table_content in table_contents:
      content +=  f"""  - pattern:
      table: {table_content["table"]}
      event: result
      code: {table_content["code"]}
    columns:
      numeric_value: col(numeric_value)
      text_value: col(text_value)
"""

    with open(out_file, "w", encoding="utf8") as f:
        f.write(content)

    print(f"Created: {out_file}")

# %%
base_path = Path("/workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept")

for category_name in data_by_cat.keys():
    # folder = base_path / category_name.replace(" ", "_").replace("/", "_per_")
    folder = base_path
    folder.mkdir(parents=True, exist_ok=True)
    for cnpt in (category := data_by_cat[category_name]).keys() :
        create_src_specific_cnpt(folder,
        category[cnpt][0]["name"].replace(" ", "_").replace("/", "_per_"),
        category[cnpt][0]["unit"] if isinstance(category[cnpt][0]["unit"], list) else category[cnpt][0]["unit"] ,
        [{"table": category[cnpt][i]["table"], "code": category[cnpt][i]["code"]} for i in range(len(category[cnpt]))]
        )
        create_general_cnpt(Path("/workspaces/OpenICU-Example/custom/generated/temp/config/concept") / category_name.replace(" ", "_").replace("/", "_per_"), category[cnpt][0]["name"].replace(" ", "_").replace("/", "_per_"),
        category[cnpt][0]["unit"] if isinstance(category[cnpt][0]["unit"], list) else category[cnpt][0]["unit"] ,
        [{"table": category[cnpt][i]["table"], "code": category[cnpt][i]["code"]} for i in range(len(category[cnpt]))])
# Out:
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/glucose.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/glucose.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/potassium.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/potassium.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/bilirubin_direct.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/bilirubin_direct.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/alanine_aminotransferase.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/alanine_aminotransferase.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/sodium.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/sodium.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/phosphate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/phosphate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/total_bilirubin.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/total_bilirubin.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/creatinine.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/creatinine.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/chloride.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/chloride.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/alkaline_phosphatase.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/alkaline_phosphatase.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/troponin_I.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/troponin_I.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/creatine_kinase.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/creatine_kinase.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/C-reactive_protein.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/C-reactive_protein.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/creatine_kinase_MB.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/creatine_kinase_MB.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/troponin_t.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/troponin_t.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/calcium.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/calcium.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/bicarbonate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/bicarbonate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/magnesium.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/magnesium.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/aspartate_aminotransferase.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/aspartate_aminotransferase.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/blood_urea_nitrogen.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/blood_urea_nitrogen.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/albumin.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/chemistry/albumin.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/patient_weight.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/demographics
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/demographics/patient_weight.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/patient_height.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/demographics
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/demographics/patient_height.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/methemoglobin.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas/methemoglobin.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/O2_partial_pressure.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas/O2_partial_pressure.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/lactate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas/lactate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/CO2_partial_pressure.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas/CO2_partial_pressure.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/base_excess.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas/base_excess.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/pH_of_blood.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas/pH_of_blood.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/fraction_of_inspired_oxygen.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas/fraction_of_inspired_oxygen.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/totcal_CO2.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas/totcal_CO2.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/calcium_ionized.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/blood_gas/calcium_ionized.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/dopamine_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications/dopamine_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/epinephrine_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications/epinephrine_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/dobutamine_duration.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications/dobutamine_duration.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/phenylephrine_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications/phenylephrine_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/norepinephrine_duration.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications/norepinephrine_duration.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/dobutamine_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications/dobutamine_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/dopamine_duration.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications/dopamine_duration.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/insulin.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications/insulin.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/vasopressin_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications/vasopressin_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/antibiotics.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications/antibiotics.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/norepinephrine_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications/norepinephrine_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/epinephrine_duration.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications/epinephrine_duration.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/dextrose_(as_D10).yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/medications/dextrose_(as_D10).yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/arterial_oxygen_saturation.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/respiratory
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/respiratory/arterial_oxygen_saturation.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/respiratory_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/respiratory
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/respiratory/respiratory_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/oxygen_saturation.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/respiratory
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/respiratory/oxygen_saturation.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/mechanical_ventilation_windows.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/respiratory
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/respiratory/mechanical_ventilation_windows.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/mean_corpuscular_volume.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/mean_corpuscular_volume.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/prothrombin_time_per_international_normalized_ratio.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/prothrombin_time_per_international_normalized_ratio.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/erythrocyte_sedimentation_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/erythrocyte_sedimentation_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/platelet_count.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/platelet_count.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/red_blood_cell_count.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/red_blood_cell_count.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/partial_thromboplastin_time.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/partial_thromboplastin_time.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/neutrophils.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/neutrophils.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/band_form_neutrophils.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/band_form_neutrophils.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/erythrocyte_distribution_width.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/erythrocyte_distribution_width.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/basophils.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/basophils.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/mean_corpuscular_hemoglobin_concentration.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/mean_corpuscular_hemoglobin_concentration.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/prothrombine_time.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/prothrombine_time.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/eosinophils.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/eosinophils.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/fibrinogen.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/fibrinogen.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/white_blood_cell_count.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/white_blood_cell_count.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/hemoglobin.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/hemoglobin.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/mean_corpuscular_hemoglobin.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/mean_corpuscular_hemoglobin.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/lymphocytes.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/lymphocytes.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/Hemoglobin_A1C.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/Hemoglobin_A1C.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/hematocrit.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/hematology/hematocrit.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/urine_output.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/output
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/output/urine_output.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/Richmond_agitation_sedation_scale.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/neurological
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/neurological/Richmond_agitation_sedation_scale.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/GCS_verbal.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/neurological
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/neurological/GCS_verbal.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/GCS_motor.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/neurological
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/neurological/GCS_motor.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/GCS_eye.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/neurological
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/neurological/GCS_eye.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/mean_arterial_pressure.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/vitals
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/vitals/mean_arterial_pressure.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/temperature.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/vitals
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/vitals/temperature.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/diastolic_blood_pressure.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/vitals
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/vitals/diastolic_blood_pressure.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/endtidal_CO2.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/vitals
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/vitals/endtidal_CO2.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/systolic_blood_pressure.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/vitals
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/vitals/systolic_blood_pressure.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/mimic-iv/concept/heart_rate.yml
# /workspaces/OpenICU-Example/custom/generated/temp/config/concept/vitals
# Created: /workspaces/OpenICU-Example/custom/generated/temp/config/concept/vitals/heart_rate.yml

# %%
# Run pipeline.ipynb

# %% [markdown]
# # Sanity check

# %%
# Prepare needed information to make check inside of ricu/ R

# Root folder were the concepts are saved
cnpt_root_folder = Path("/workspaces/OpenICU-Example/output/project/workspace/concept")

found_data_info = {}

# iterate all the folders in the root folder
for cnpt_folder in cnpt_root_folder.iterdir():
    # if the cnpt_folder is a folder/directory execute logic
    if cnpt_folder.is_dir():
        # select the first file in the sub folder "/1.0.0/" and exprect it to be the cnpt_file
        cnpt_file  = next((file for file in (cnpt_folder / "1.0.0").iterdir() if file.is_file()), None)
        # print(f"{cnpt_folder}: {cnpt_file.name if cnpt_file else "empty"}")
        size = len(pl.read_parquet(cnpt_file))
        # print(size)
        name = cnpt_folder.name
        if data_by_cnpt.get(name):
            found_data_info[name] = data_by_cnpt[name]
        else:
            print("Not found: ", name)

# %%
with open("check-open_icu-to-ricu.json", "w") as file:
    json.dump(found_data_info, file, indent=4, ensure_ascii=False)
# found_data_info

# %% [markdown]
# ## Make Checklist for Github

# %%
def make_issue_checklist(ricu: pl.DataFrame):
    cat = {}

    for col in ricu.columns:
        elem = list(ricu[col])[0]
        if not cat.get(elem["category"]):
            cat[elem["category"]] = []
        cat[elem["category"]] += [elem["description"]]
    output = ""
    for cat, cnpts in cat.items():
        output += f"- [ ] {cat}:\n"
        for cnpt in cnpts:
            output += ((f"  - [x] {cnpt}\n") if (cnpt.replace(" ", "_").replace("/", "_per_") in data_by_cnpt.keys()) else (f"  - [ ] {cnpt}\n"))
            if (cnpt.replace(" ", "_").replace("/", "_per_") not in data_by_cnpt.keys()):
                print(f"{cnpt}")
    return output

# %%
output = make_issue_checklist(ricu_cnpt_dict_df)
# Out:
# SaO2/FiO2
# Horowitz index
# ventilation durations
# tracheostomy
# ventilation start
# ventilation end
# supplemental oxygen
# patient body mass index
# patient admission type
# patient sex
# patient age
# carboxyhemoglobin
# vasopressor indicator
# norepinephrine equivalents
# dobutamine administration for min 1h
# corticosteroids
# urine output per 24h
# ICU length of stay
# SOFA liver component
# national early warning score
# sepsis-3 criterion
# hospital length of stay
# SOFA coagulation component
# suspected infection
# quick SOFA score
# SOFA cardiovascular component
# dopamine administration for min 1h
# norepinephrine administration for min 1h
# in hospital mortality
# epinephrine administration for min 1h
# systemic inflammatory response syndrome score
# sequential organ failure assessment score
# SOFA respiratory component
# SOFA central nervous system component
# modified early warning score
# SOFA renal component
# GCS total
# AVPU scale
# Glasgow coma scale (non-sedated)
# body fluid sampling
