# %%
import os
os.environ["HYDRA_FULL_ERROR"] = "1"

# %%
# !rm -rf /workspaces/OpenICU.example/output/project/MEDS_extract-MIMIC_IV-root_output_dir/MEDS_cohort

# %%
# !MEDS_extract-MIMIC_IV root_output_dir=/workspaces/OpenICU.example/output/project/MEDS_extract-MIMIC_IV-root_output_dir do_demo=True do_download=False do_overwrite=True
# Out:
# [2026-04-01 13:18:24,036][MIMIC_IV_MEDS.__main__][INFO] - Skipping data download.
# Done with hosp/services. Continuing
# Done with hosp/drgcodes. Continuing
# Done with hosp/labevents. Continuing
# Done with hosp/d_labitems. Continuing
# Done with hosp/procedures_icd. Continuing
# Done with hosp/admissions. Continuing
# Done with hosp/poe. Continuing
# Done with hosp/microbiologyevents. Continuing
# Done with hosp/patients. Continuing
# Done with hosp/omr. Continuing
# Done with hosp/pharmacy. Continuing
# Done with hosp/hcpcsevents. Continuing
# Done with hosp/poe_detail. Continuing
# Done with hosp/emar. Continuing
# Done with hosp/diagnoses_icd. Continuing
# Done with hosp/prescriptions. Continuing
# Done with hosp/emar_detail. Continuing
# Done with hosp/provider. Continuing
# Done with hosp/transfers. Continuing
# Done with hosp/d_hcpcs. Continuing
# Done with icu/icustays. Continuing
# Done with icu/outputevents. Continuing
# Done with icu/d_items. Continuing
# ...

# %%
# !MEDS_extract-MIMIC_IV --help
# Out:
# full_extraction_2026-04-01_13-18-45 is powered by Hydra.
#
# == Configuration groups ==
# Compose your configuration from those groups (group=option)
#
#
#
# == Config ==
# Override anything in the config (foo.bar=value)
#
# root_output_dir: ???
# raw_input_dir: ${root_output_dir}/raw_input
# pre_MEDS_dir: ${root_output_dir}/pre_MEDS
# MEDS_cohort_dir: ${root_output_dir}/MEDS_cohort
# stage_runner_fp: null
# do_download: true
# do_overwrite: false
# do_copy: false
# do_demo: false
# log_dir: ${root_output_dir}/.logs
#
#
# Powered by Hydra (https://hydra.cc)
# Use --hydra-help to view Hydra specific help
