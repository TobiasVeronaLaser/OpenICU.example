# %% [markdown]
# ### Removed indentation error

# %%
# from pathlib import Path

# fp = Path("/home/vscode/.local/lib/python3.13/site-packages/MEDS_transforms/mapreduce/utils.py")

# lines = fp.read_text().splitlines()

# for i in range(160, 190):
#     print(f"{i+1:4d}: {lines[i]}")

# %%
# text = fp.read_text()

# # kaputte Variante fixen
# text = text.replace(
#     "lock_fp.unlink()",
#     "    lock_fp.unlink()"
# )

# fp.write_text(text)

# print("Fixed indentation.")

# %%
# lines = fp.read_text().splitlines()

# for i in range(170, 180):
#     print(f"{i+1:4d}: {lines[i]}")
