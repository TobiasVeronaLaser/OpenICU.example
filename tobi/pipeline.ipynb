# %%
from pathlib import Path

from open_icu import OpenICUProject, ExtractionStep, ConceptStep

config_path = Path.cwd() / "config" 
project_path = Path.cwd() / "output" / "project"
with OpenICUProject(project_path) as project:
 
    extraction_step = ExtractionStep.load(project, config_path / "extraction.yml")
    extraction_step.run()

    concept_step = ConceptStep.load(project, config_path / "concept.yml")
    concept_step.run()
# Out:
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.outputevents
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.procedureevents
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.ingredientevents
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.omr
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.inputevents
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.labevents
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.hcpcsevents
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.prescriptions
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.emar
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.diagnoses_icd
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.chartevents
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.admissions
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.patients
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.microbiologyevents
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.datetimeevent
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.drgcodes
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.icustays
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.mimic-iv.3.1.services
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.eicu.2.0.patient
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.eicu.2.0.infusiondrug
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.eicu.2.0.vitalperiodic
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.eicu.2.0.medication
# 2026-02-08 18:33:20 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.dataset.eicu.2.0.lab
# 2026-02-08 18:33:21 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.creatinine.1.0.0
# 2026-02-08 18:33:21 [INFO] open_icu.config.registry: Skip loading configuration: openicu.config.concept.potassium.1.0.0
# 2026-02-08 18:33:21 [INFO] open_icu.config.registry: Loaded configuration: openicu.config.concept.antibiotics.1.0.0
# 2026-02-08 18:33:21 [INFO] open_icu.steps.concept.step: extracting concept: creatinine
# 2026-02-08 18:33:23 [INFO] open_icu.steps.concept.step: extracting concept: antibiotics
